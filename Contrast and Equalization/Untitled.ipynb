# %%
import skimage
import numpy as np
from matplotlib import pyplot as plt
from os import listdir
from os.path import isfile, isdir, join
import cv2

# %%
img = cv2.imread('piece4.jpg', 0)
plt.imshow(img, cmap='gray')
plt.show()
cv2.imwrite('test2.png', img)
# Out:
# True

# %%
img = np.where(img >= 0, ((img - img.min()) / (img.max() - img.min())) * 255, 0)
print(img)
# Out:
# [[235.16666667 235.16666667 235.16666667 ... 236.58333333 236.58333333
#   236.58333333]
#  [235.16666667 235.16666667 235.16666667 ... 236.58333333 236.58333333
#   236.58333333]
#  [235.16666667 235.16666667 235.16666667 ... 236.58333333 236.58333333
#   236.58333333]
#  ...
#  [114.75       114.75       114.75       ... 211.08333333 211.08333333
#   211.08333333]
#  [114.75       114.75       114.75       ... 211.08333333 211.08333333
#   211.08333333]
#  [114.75       114.75       114.75       ... 211.08333333 212.5
#   212.5       ]]

# %%
plt.imshow(img, cmap='gray')
plt.show()
cv2.imwrite('test.png', img)
# Out:
# True

# %%
clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
cl = clahe.apply(img)
cv2.imshow('CLAHE output', cl)
