# %%
import numpy as np
from skimage import io
import skimage
from matplotlib import pyplot as plt

# %%
img_gray = io.imread('smarties_.jpg', as_gray =True)
img = io.imread('smarties_.jpg')

# %%
plt.imshow(img_gray, cmap='gray')
plt.show()

# %%
neg = np.negative(img)
plt.imshow(neg)
plt.show()

# %%
seuil = np.mean(img_gray)
bin_img = 1.0 * (img_gray < seuil)

labels = skimage.measure.label(bin_img)
print(str(len(np.unique(labels)[1:])) + ' smarties dans l\'image.')

plt.imshow(regions)
plt.show()
# Out:
# 9 smarties dans l'image.

# %%
img_gray = io.imread('smarties.jpg', as_gray =True)

# %%
seuil = np.mean(img_gray)
bin_img = 1.0 * (img_gray < seuil)

labels = skimage.measure.label(bin_img)
print(str(len(np.unique(labels)[1:])) + ' smarties dans l\'image.')

plt.imshow(labels)
plt.show()
# Out:
# 25 smarties dans l'image.
